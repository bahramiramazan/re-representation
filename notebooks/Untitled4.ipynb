# %%
y=[
    #'google_easy_head_sim',\
    #'google_hard_head_sim',\
    #'google_easy_head_sim_',\
    #'google_hard_head_sim_',\


    'Easy_easy+',\
    'Easy_hard+',\

    'Easy_easy-',\
    'Easy_hard-',\

    'Hard_easy+',\
    'Hard_hard+',\

    'Hard_easy-',\
    'Hard_hard-',\


    'ekar_easy+',\
    'ekar_hard+',\

    'ekar_easy-',\
    'ekar_hard-',\


    'baseline_easy+',\
    'baseline_hard+',\

    'baseline_easy-',\
    'baseline_hard-',\



  ]
print(len(y))
    
import plotly.express as px
# _hard
data=[\
   #baseline_google_easy_head_dist,\
   #baseline_google_hard_head_dist,\
   #baseline_google_easy_head_dist_,\
   #baseline_google_hard_head_dist_,\

   easy_sentence_route_train_semeval_2012_easy_head_dist,\
   easy_sentence_route_train_semeval_2012_hard_head_dist,\
   easy_sentence_route_train_semeval_2012_easy_head_dist_,\
   easy_sentence_route_train_semeval_2012_hard_head_dist_,\

   hardp_sentence_route_train_semeval_2012_easy_head_dist,\
   hardp_sentence_route_train_semeval_2012_hard_head_dist,\
   hardp_sentence_route_train_semeval_2012_easy_head_dist_,\
   hardp_sentence_route_train_semeval_2012_hard_head_dist_,\


    
   ekarp_sentence_route_train_semeval_2012_easy_head_dist,\
   ekarp_sentence_route_train_semeval_2012_hard_head_dist,\
   ekarp_sentence_route_train_semeval_2012_easy_head_dist_,\
   ekarp_sentence_route_train_semeval_2012_hard_head_dist_,\



    baseline_semeval_2012_easy_head_dist,\
   baseline_semeval_2012_hard_head_dist,\
   baseline_semeval_2012_easy_head_dist_,\
   baseline_semeval_2012_hard_head_dist_,\


     
     ]
print(len(data))
fig = px.imshow(data,
                labels=dict(x="hidden layers", y="", color="Distance"),
                x=[i for i in range(len(tail_sim_))],
                y=y
               )

fig.update_layout(uniformtext_minsize=40)
fig.update_xaxes(side="top")
fig.update_layout(
    height=600,
    title_text='Baseline,cosine similarity'
)
fig.write_image("../images/sim_semeval_dis.jpeg")

# %%
#dataname semeval_2012_easy
baseline_semeval_2012_easy_head_sim= [0.9119414687156677, 0.9569517970085144, 0.971916675567627, 0.9710406064987183, 0.9633376598358154, 0.9684627056121826, 0.9718777537345886, 0.9779074192047119, 0.9822325706481934, 0.9844964742660522, 0.985734760761261, 0.9837297797203064, 0.9835827946662903, 0.9842021465301514, 0.9839881658554077, 0.980552613735199, 0.9813462495803833, 0.9819740056991577, 0.9837766885757446, 0.9849584698677063, 0.9832010269165039, 0.9854800701141357, 0.986491322517395, 0.9858819246292114, 0.9957109093666077]
baseline_semeval_2012_easy_head_dist= [45.97565841674805, 43.8851432800293, 40.421112060546875, 42.52238082885742, 45.2972412109375, 45.35920333862305, 45.83867645263672, 43.93709945678711, 42.768062591552734, 40.7017822265625, 40.14251708984375, 39.46681213378906, 40.1076774597168, 40.15515899658203, 40.116519927978516, 41.67513656616211, 41.72377014160156, 40.469505310058594, 39.32655715942383, 38.33659744262695, 38.772010803222656, 39.437034606933594, 40.1041259765625, 40.653564453125, 31.23748016357422]
