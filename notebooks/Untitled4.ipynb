# %% [markdown]
# ## Oberervations
# * the plot for the  observation of re-represenation in nn
# * the similarity for each layers, is printed at the after evaluating in a given dataset,

# %%
y=[
   


  ]
print(len(y))
    
import plotly.express as px
# _hard
data=[\
   
     
     ]
print(len(data))
fig = px.imshow(data,
                labels=dict(x="hidden layers", y="", color="Distance"),
                x=[i for i in range(len(tail_sim_))],
                y=y
               )

fig.update_layout(uniformtext_minsize=40)
fig.update_xaxes(side="top")
fig.update_layout(
    height=600,
    title_text='Baseline,cosine similarity'
)
fig.write_image("../images/similarity.jpeg")
